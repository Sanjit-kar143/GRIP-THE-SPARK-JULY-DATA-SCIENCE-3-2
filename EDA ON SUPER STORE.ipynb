# %% [markdown]
# #                                   THE SPARK FOUNDATION

# %% [markdown]
# #### DATA SCIENCE & BUSSINESS ANALYTICS

# %% [markdown]
# NAME : SANJIT KUMAR KAR
#
# EMAIL ID : sanjitkar661@gmail.com
#
# LINKEDIN PROFILE : https://www.linkedin.com/in/sanjit-kumar-kar-a0a92515b

# %% [markdown]
# ### PROJECT 3: EXPLORATORY DATA ANALYSIS ON SAMPLE SUPER STORE

# %%
#import The libraries Requirement for this Notebook
import pandas as pd
import numpy as np                   #used for numerical calculation
import matplotlib.pyplot as plt      #used for data visualization
# %matplotlib inline
import seaborn as sns                #plotting graph
import warnings                    
                                    
warnings.filterwarnings("ignore")   #Ignore warning

# %%
data =pd.read_csv('SampleSuperstore.csv')

# %%
data.head(n=15)
# Out:
#          Ship Mode      Segment        Country             City  \
# 0     Second Class     Consumer  United States        Henderson
# 1     Second Class     Consumer  United States        Henderson
# 2     Second Class    Corporate  United States      Los Angeles
# 3   Standard Class     Consumer  United States  Fort Lauderdale
# 4   Standard Class     Consumer  United States  Fort Lauderdale
# 5   Standard Class     Consumer  United States      Los Angeles
# 6   Standard Class     Consumer  United States      Los Angeles
# 7   Standard Class     Consumer  United States      Los Angeles
# 8   Standard Class     Consumer  United States      Los Angeles
# 9   Standard Class     Consumer  United States      Los Angeles
# 10  Standard Class     Consumer  United States      Los Angeles
# 11  Standard Class     Consumer  United States      Los Angeles
# 12  Standard Class     Consumer  United States          Concord
# 13  Standard Class     Consumer  United States          Seattle
# ...

# %%
data.columns
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %%
data.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
data.shape
# Out:
# (9994, 13)

# %%
data.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
data.max()
# Out:
# Ship Mode       Standard Class
# Segment            Home Office
# Country          United States
# City                      Yuma
# State                  Wyoming
# Postal Code              99301
# Region                    West
# Category            Technology
# Sub-Category            Tables
# Sales                 22638.48
# Quantity                    14
# Discount                   0.8
# Profit                8399.976
# dtype: object

# %%
data.min()
# Out:
# Ship Mode         First Class
# Segment              Consumer
# Country         United States
# City                 Aberdeen
# State                 Alabama
# Postal Code              1040
# Region                Central
# Category            Furniture
# Sub-Category      Accessories
# Sales                   0.444
# Quantity                    1
# Discount                  0.0
# Profit              -6599.978
# dtype: object

# %%
# clean unnecessary coulmns
data = data.drop(['Country'] , axis=1)
data.head()
# Out:
#         Ship Mode    Segment             City       State  Postal Code Region  \
# 0    Second Class   Consumer        Henderson    Kentucky        42420  South
# 1    Second Class   Consumer        Henderson    Kentucky        42420  South
# 2    Second Class  Corporate      Los Angeles  California        90036   West
# 3  Standard Class   Consumer  Fort Lauderdale     Florida        33311  South
# 4  Standard Class   Consumer  Fort Lauderdale     Florida        33311  South
#
#           Category Sub-Category     Sales  Quantity  Discount    Profit
# 0        Furniture    Bookcases  261.9600         2      0.00   41.9136
# 1        Furniture       Chairs  731.9400         3      0.00  219.5820
# 2  Office Supplies       Labels   14.6200         2      0.00    6.8714
# 3        Furniture       Tables  957.5775         5      0.45 -383.0310
# 4  Office Supplies      Storage   22.3680         2      0.20    2.5164

# %%
#finding any missing value
data.isna().any()
# Out:
# Ship Mode       False
# Segment         False
# City            False
# State           False
# Postal Code     False
# Region          False
# Category        False
# Sub-Category    False
# Sales           False
# Quantity        False
# Discount        False
# Profit          False
# dtype: bool

# %%
data.duplicated().sum()
# Out:
# 17

# %%
#cleaning unnecessary columns
data.drop_duplicates()
data.head()
# Out:
#         Ship Mode    Segment             City       State  Postal Code Region  \
# 0    Second Class   Consumer        Henderson    Kentucky        42420  South
# 1    Second Class   Consumer        Henderson    Kentucky        42420  South
# 2    Second Class  Corporate      Los Angeles  California        90036   West
# 3  Standard Class   Consumer  Fort Lauderdale     Florida        33311  South
# 4  Standard Class   Consumer  Fort Lauderdale     Florida        33311  South
#
#           Category Sub-Category     Sales  Quantity  Discount    Profit
# 0        Furniture    Bookcases  261.9600         2      0.00   41.9136
# 1        Furniture       Chairs  731.9400         3      0.00  219.5820
# 2  Office Supplies       Labels   14.6200         2      0.00    6.8714
# 3        Furniture       Tables  957.5775         5      0.45 -383.0310
# 4  Office Supplies      Storage   22.3680         2      0.20    2.5164

# %%
data.nunique()
# Out:
# Ship Mode          4
# Segment            3
# City             531
# State             49
# Postal Code      631
# Region             4
# Category           3
# Sub-Category      17
# Sales           5825
# Quantity          14
# Discount          12
# Profit          7287
# dtype: int64

# %%
#check for outliers
data.boxplot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### DATA DISTRIBUTION OF OTHER PARAMETER

# %%
sns.pairplot(data=data,hue='Region')
plt.show()

# %%
#visulization
data.corr()
plt.figure(figsize=(15,8))
sns.heatmap(data.corr(),annot=True)
plt.show()

# %%
data.plot.scatter(x="Discount",y="Profit",c="green",s=40,figsize=(12,5))
plt.show()

# %%
#all data in one code
sns.set_palette('viridis')
sns.pairplot(data)
plt.show()

# %% [markdown]
# #### SALES REPRESENTATION

# %%
#creat a bar graph(catagory vs sales) 
plt.bar('Category','Sales',data=data,color='green')
plt.title('Sales vs Category',size=15)
plt.xlabel('Caetgory',size=10)
plt.ylabel('Sales',size=10)
plt.show()

# %%
#Shipping Model
plt.figure(figsize=(6,5))
sns.countplot('Ship Mode',data=data)
plt.title('Popular Shipping Modes',size=14)
plt.xlabel('\n Shipping mode',size=12)
plt.ylabel('Number of orders',size=12)
plt.xticks(fontsize=10)
plt.show()

# %%
#Quantities Order by Each Segment
data_group = data.groupby('Segment')['Quantity'].sum().reset_index()
print(data_group)
labels =data['Segment'].unique()
colors=['green','blue','pink']
plt.figure(figsize=(5,5))
plt.pie(data_group['Quantity'],autopct='%1.1f%%',labels=labels,explode=(0.02,0.02,0.02),colors=colors)
plt.title('Quantities ordered by each segement',size=15)
plt.show()
# Out:
#        Segment  Quantity
# 0     Consumer     19521
# 1    Corporate     11608
# 2  Home Office      6744

# %%
#shiping mode vs count
sns.catplot('Ship Mode',data=data,hue='Segment',kind='count',aspect=1.5,height=6)
plt.show()

# %%
#Quantity Order by Cities
sns.catplot('State',kind='count',data=data,palette='Set1',height=6,aspect=2.3)
plt.xticks(rotation=90)
plt.show()

# %%
#Quantities ordered Region wise
data_region = data.groupby('Region')['Quantity'].sum().reset_index()
print(data_group)
labels =data_region['Region'].unique()
plt.figure(figsize=(5,5))
plt.pie(data_region['Quantity'],autopct='%1.1f%%',explode=(0.02,0.02,0.02,0.02),)
plt.title('Quantities ordered by each region',size=13)
plt.show()
# Out:
#     Region  Quantity
# 0  Central      8780
# 1     East     10618
# 2    South      6209
# 3     West     12266

# %%
#most profitable product
datatop10_items=data.groupby('Sub-Category')['Profit'].sum().reset_index().sort_values(by='Profit',ascending=False)
datatop10_items.reset_index(drop=True,inplace=True)
datatop10_items=datatop10_items.head(10)
datatop10_items
# Out:
#   Sub-Category      Profit
# 0      Copiers  55617.8249
# 1       Phones  44515.7306
# 2  Accessories  41936.6357
# 3        Paper  34053.5693
# 4      Binders  30221.7633
# 5       Chairs  26590.1663
# 6      Storage  21278.8264
# 7   Appliances  18138.0054
# 8  Furnishings  13059.1436
# 9    Envelopes   6964.1767

# %%
#Highest Selling Categories
data_cats = data.groupby('Category')['Quantity'].sum().reset_index()
data_cats
# Out:
#           Category  Quantity
# 0        Furniture      8028
# 1  Office Supplies     22906
# 2       Technology      6939

# %%
#Visualizing the Top 10 Profitable Products
sns.catplot('Sub-Category','Profit',data=datatop10_items,kind='bar',aspect=1.5,height=9)
plt.title('Top 10 profitable products',size=30)
plt.xticks(size=15)
plt.yticks(size=15)
plt.ylabel('Cumulative profit',size=20)
plt.xlabel('Products',size=20)
plt.show()

# %%
#Top Profitable Cities
datatop10_cities=data.groupby('City')['Profit'].sum().reset_index().sort_values(by='Profit',ascending=False)
datatop10_cities = datatop10_cities.head(10)
datatop10_cities
# Out:
#               City      Profit
# 329  New York City  62036.9837
# 266    Los Angeles  30440.7579
# 452        Seattle  29156.0967
# 438  San Francisco  17507.3854
# 123        Detroit  13181.7908
# 233      Lafayette  10018.3876
# 215        Jackson   7581.6828
# 21         Atlanta   6993.6629
# 300    Minneapolis   6824.5846
# 437      San Diego   6377.1960

# %%
#Top 10 Cities
sns.catplot('City','Profit',data=datatop10_cities,kind='bar',aspect=2,height=8)
plt.title('Top 10 cities with profit inflow',size=25)
plt.xticks(size=15)
plt.yticks(size=15)
plt.ylabel('Cumulative profit',size=18)
plt.xlabel('City',size=15)
plt.show()

# %% [markdown]
# ## CONCLUSION

# %% [markdown]
# ##### DATA: QUALITY IS SO GOOD OF DATA SET.NO NULL VALUE IN DATASET.
# SHIPPING MODE : 'Standard class'is highest
#
# CITY = "New York" is the Highest Profitble city
#
# PRODUCT ="Copiers"is the highest profitble product
#
# SEGEMENT="HomeOffice"generates least sale
#
# CATEGORY="Technology" highest sales
